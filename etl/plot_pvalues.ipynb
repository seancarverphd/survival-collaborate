# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import seaborn as sns

# %%
f = open('../analysis/pvalues.savepkl','rb')
zstats = pickle.load(f)
pvalues = pickle.load(f)
f.close()

# %%
#ax = sns.stripplot(x=, y="total_bill", data=pvalues)

# %%
pv = pd.Series(pvalues)

# %%
pv.drop('',inplace=True)

# %%
pval = pd.DataFrame({"pvalue":pv})
pval['group'] = 'Data'

# %%
ax = sns.violinplot(x='group', y='pvalue', data=pval)

# %%
len(pvalues)
# Out:
# 2847

# %%
np.random.seed(0)

# %%
fake1 = np.random.rand(2846)

# %%
fake2 = np.random.rand(2846)

# %%
fake3 = np.random.rand(2846)

# %%
f1 = pd.DataFrame({"pvalue":fake1})
f1['group'] = 'Fake_1'

# %%
f2 = pd.DataFrame({"pvalue":fake2})
f2['group'] = 'Fake_2'

# %%
f3 = pd.DataFrame({"pvalue":fake3})
f3['group'] = 3

# %%
all_groups = pd.concat([pval, f1, f2])

# %%
sns.violinplot(x='group', y='pvalue', data=all_groups, inner='stick')
#print(plt.xlim())
plt.plot([-0.5,2.5], [0.05,0.05], linewidth=2, color='red')
plt.savefig("pvalues_with_fake.pdf")
